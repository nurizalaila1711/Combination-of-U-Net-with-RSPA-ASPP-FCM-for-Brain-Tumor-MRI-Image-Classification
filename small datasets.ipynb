# %%
from google.colab import drive
drive.mount('/content/gdrive')
import zipfile
local_zip = '/content/gdrive/MyDrive/Dataset_364.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content/dataset')
# Out:
# Mounted at /content/gdrive

# %%
import os
import cv2
import io
import numpy as np
import pandas as pd
import tensorflow as tf
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from warnings import filterwarnings
from IPython.display import display,clear_output
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report,confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
for dirname, _, filenames in os.walk('/content/dataset'):
  for filename in filenames:
    (os.path.join(dirname, filename))

# %%
labels = ['glioma', 'meningioma', 'pituitary']

# %% [markdown]
# # Data Preparation

# %%
X_train = []
y_train = []
image_size = 200
for i in labels:
  folderPath = os.path.join('../content/dataset/Dataset_364',i)
  for j in tqdm(os.listdir(folderPath)):
    img = cv2.imread(os.path.join(folderPath,j))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = np.array(img)
    img = img.astype('float32')/255.0
    img = cv2.resize(img,(image_size, image_size))
    img = np.expand_dims(img, axis=-1)
    X_train.append(img)
    y_train.append(i)

X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 170/170 [00:01<00:00, 88.21it/s]
# 100%|██████████| 90/90 [00:00<00:00, 95.96it/s]
# 100%|██████████| 110/110 [00:01<00:00, 95.69it/s]

# %%
X_train.shape
# Out:
# (370, 200, 200, 1)

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=42)

# %%
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=2,
    height_shift_range=2,
    zoom_range=[0.8, 1.2],
    horizontal_flip=True)

datagen.fit(X_train)
X_train.shape
# Out:
# (370, 200, 200, 1)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.2, random_state=42)

print("Train:", X_train.shape,
      "\nTest:", X_test.shape,)
# Out:
# Train: (296, 200, 200, 1)
# Test: (74, 200, 200, 1)

# %%
y_train_new = []
for i in y_train:
  y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
  y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %% [markdown]
# # **Train Model**

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPool2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Conv1D, Add, Activation, Reshape
from tensorflow.keras import layers

def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, activation='relu', padding="same")(inputs)
    x = Conv2D(num_filters, 3, activation='relu', padding="same")(x)
    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = concatenate([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras import Model

class StripPooling(layers.Layer):
    def __init__(self, pool_size, **kwargs):
        super(StripPooling, self).__init__(**kwargs)
        self.pool_size = pool_size
        self.adaptive_pool1 = layers.Lambda(lambda x: tf.reduce_max(x, axis=1, keepdims=True))
        self.adaptive_pool2 = layers.Lambda(lambda x: tf.reduce_max(x, axis=2, keepdims=True))
        self.conv1d_1 = Conv1D(filters=128, kernel_size=3, activation='relu', padding="same")
        self.conv1d_2 = Conv1D(filters=128, kernel_size=3, activation='relu', padding="same")
        self.conv1d_3 = Conv2D(filters=128, kernel_size=1, activation='sigmoid', padding="same")
        self.add_1 = layers.Add()
        self.multiply = layers.Multiply()
        self.add_2 = layers.Add()
        self.relu = layers.ReLU()
        self.batch_norm = BatchNormalization()

    def call(self, inputs):
        pool1 = self.adaptive_pool1(inputs)
        pool2 = self.adaptive_pool2(inputs)

        conv1d_1_out = self.conv1d_1(pool1)
        conv1d_2_out = self.conv1d_2(pool2)

        expand1 = tf.expand_dims(conv1d_1_out, axis=2)
        expand2 = tf.expand_dims(conv1d_2_out, axis=1)

        fusion = self.add_1([expand1, expand2])

        conv1d_3_out = self.conv1d_3(fusion)

        multiply_out = self.multiply([inputs, conv1d_3_out])

        residual = self.add_2([inputs, multiply_out])

        out = self.relu(residual)
        out = self.batch_norm(out)

        return out

# %%
def aspp(inputs):
    conv1 = Conv2D(64, kernel_size=3, strides=1, dilation_rate=1, padding='same')(inputs)
    bn1 = BatchNormalization()(conv1)
    relu1 = layers.ReLU()(bn1)

    # Block 2
    conv2 = Conv2D(64, kernel_size=3, strides=1, dilation_rate=3, padding='same')(inputs)
    bn2 = BatchNormalization()(conv2)
    relu2 = layers.ReLU()(bn2)

    # Block 3
    conv3 = Conv2D(64, kernel_size=3, strides=1, dilation_rate=5, padding='same')(inputs)
    bn3 = BatchNormalization()(conv3)
    relu3 = layers.ReLU()(bn3)

    # Block 4
    conv4 = Conv2D(256, kernel_size=1, strides=1)(inputs)
    bn4 = BatchNormalization()(conv4)
    relu4 = layers.ReLU()(bn4)
    pool4 = layers.MaxPooling2D(pool_size=(2, 2), strides=1, padding='same')(inputs)

    # Block 5
    concatenated_features = concatenate([relu1, relu2, relu3, relu4, pool4], axis=-1)
    conv5 = Conv2D(512, kernel_size=1, strides=1)(concatenated_features)
    bn5 = BatchNormalization()(conv5)
    relu5 = layers.ReLU()(bn5)

    x = relu5

    return x

# %%
def fcm(inputs, num_classes):
    # Fully connected layer 1
    x = Conv2D(filters=256, kernel_size=3)(inputs)
    x = BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(0.2)(x)

    # Fully connected layer 2
    x = Conv2D(filters=128, kernel_size=3)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = layers.Dropout(0.2)(x)

    # Fully connected layer 3
    x = Conv2D(filters=num_classes, kernel_size=3)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Flatten()(x)

    return x

# %%
from tensorflow.keras import regularizers
#L2 regularization parameter
l2_reg = 0.0001

# %%
def build_model(input_shape):
    inputs = Input(input_shape)
    s1, p1 = encoder_block(inputs, 128)
    s2, p2 = encoder_block(p1, 256)
    s3, p3 = encoder_block(p2, 512)
    b1 = conv_block(p3, 1024)
    d1 = decoder_block(b1, s3, 512)
    d2 = decoder_block(d1, s2, 256)
    d3 = decoder_block(d2, s1, 128)
    o1 = StripPooling(pool_size=(200, 200))(d3)
    o2 = tf.squeeze(o1, axis=1)
    o3 = aspp(o2)
    o4 = fcm(o3, 3)
    predictions = layers.Dense(3, kernel_regularizer=regularizers.l2(l2_reg), activation='softmax')(o4)

    model = Model(inputs=inputs, outputs=predictions)
    return model

# %%
height = img.shape[0]
width = img.shape[1]
channels = img.shape[2]
pool_size = (200,200)
input_shape=(height, width, channels)
model=build_model(input_shape)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 200, 200, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 200, 200, 12  1280        ['input_1[0][0]']
#                                 8)
#
#  conv2d_1 (Conv2D)              (None, 200, 200, 12  147584      ['conv2d[0][0]']
#                                 8)
#
#  max_pooling2d (MaxPooling2D)   (None, 100, 100, 12  0           ['conv2d_1[0][0]']
#                                 8)
#
#  conv2d_2 (Conv2D)              (None, 100, 100, 25  295168      ['max_pooling2d[0][0]']
#                                 6)
#
#  conv2d_3 (Conv2D)              (None, 100, 100, 25  590080      ['conv2d_2[0][0]']
#                                 6)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 256)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 50, 50, 512)  1180160     ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 50, 50, 512)  2359808     ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 512)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 25, 25, 1024  4719616     ['max_pooling2d_2[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 25, 25, 1024  9438208     ['conv2d_6[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 50, 50, 512)  2097664    ['conv2d_7[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 50, 50, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'conv2d_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 50, 50, 512)  4719104     ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 50, 50, 512)  2359808     ['conv2d_8[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 100, 100, 25  524544     ['conv2d_9[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 100, 100, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'conv2d_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 100, 100, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  conv2d_11 (Conv2D)             (None, 100, 100, 25  590080      ['conv2d_10[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 200, 200, 12  131200     ['conv2d_11[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 200, 200, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'conv2d_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 200, 200, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_13 (Conv2D)             (None, 200, 200, 12  147584      ['conv2d_12[0][0]']
#                                 8)
#
#  strip_pooling (StripPooling)   (None, 1, 200, 200,  115584      ['conv2d_13[0][0]']
#                                  128)
#
#  tf.compat.v1.squeeze (TFOpLamb  (None, 200, 200, 12  0          ['strip_pooling[0][0]']
#  da)                            8)
#
#  conv2d_15 (Conv2D)             (None, 200, 200, 64  73792       ['tf.compat.v1.squeeze[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 200, 200, 64  73792       ['tf.compat.v1.squeeze[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 200, 200, 64  73792       ['tf.compat.v1.squeeze[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 200, 200, 25  33024       ['tf.compat.v1.squeeze[0][0]']
#                                 6)
#
#  batch_normalization_1 (BatchNo  (None, 200, 200, 64  256        ['conv2d_15[0][0]']
#  rmalization)                   )
#
#  batch_normalization_2 (BatchNo  (None, 200, 200, 64  256        ['conv2d_16[0][0]']
#  rmalization)                   )
#
#  batch_normalization_3 (BatchNo  (None, 200, 200, 64  256        ['conv2d_17[0][0]']
#  rmalization)                   )
#
#  batch_normalization_4 (BatchNo  (None, 200, 200, 25  1024       ['conv2d_18[0][0]']
#  rmalization)                   6)
#
#  re_lu_1 (ReLU)                 (None, 200, 200, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  re_lu_2 (ReLU)                 (None, 200, 200, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  re_lu_3 (ReLU)                 (None, 200, 200, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  re_lu_4 (ReLU)                 (None, 200, 200, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 200, 200, 12  0          ['tf.compat.v1.squeeze[0][0]']
#                                 8)
#
#  concatenate_3 (Concatenate)    (None, 200, 200, 57  0           ['re_lu_1[0][0]',
#                                 6)                                're_lu_2[0][0]',
#                                                                   're_lu_3[0][0]',
#                                                                   're_lu_4[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 200, 200, 51  295424      ['concatenate_3[0][0]']
#                                 2)
#
#  batch_normalization_5 (BatchNo  (None, 200, 200, 51  2048       ['conv2d_19[0][0]']
#  rmalization)                   2)
#
#  re_lu_5 (ReLU)                 (None, 200, 200, 51  0           ['batch_normalization_5[0][0]']
#                                 2)
#
#  conv2d_20 (Conv2D)             (None, 198, 198, 25  1179904     ['re_lu_5[0][0]']
#                                 6)
#
#  batch_normalization_6 (BatchNo  (None, 198, 198, 25  1024       ['conv2d_20[0][0]']
#  rmalization)                   6)
#
#  activation (Activation)        (None, 198, 198, 25  0           ['batch_normalization_6[0][0]']
#                                 6)
#
#  dropout (Dropout)              (None, 198, 198, 25  0           ['activation[0][0]']
#                                 6)
#
#  conv2d_21 (Conv2D)             (None, 196, 196, 12  295040      ['dropout[0][0]']
#                                 8)
#
#  batch_normalization_7 (BatchNo  (None, 196, 196, 12  512        ['conv2d_21[0][0]']
#  rmalization)                   8)
#
#  activation_1 (Activation)      (None, 196, 196, 12  0           ['batch_normalization_7[0][0]']
#                                 8)
#
#  dropout_1 (Dropout)            (None, 196, 196, 12  0           ['activation_1[0][0]']
#                                 8)
#
#  conv2d_22 (Conv2D)             (None, 194, 194, 3)  3459        ['dropout_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 194, 194, 3)  12         ['conv2d_22[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 194, 194, 3)  0           ['batch_normalization_8[0][0]']
#
#  dropout_2 (Dropout)            (None, 194, 194, 3)  0           ['activation_2[0][0]']
#
#  flatten (Flatten)              (None, 112908)       0           ['dropout_2[0][0]']
#
#  dense (Dense)                  (None, 3)            338727      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 33,264,758
# Trainable params: 33,261,808
# Non-trainable params: 2,950
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import metrics

# %%
optimizer = Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999)

# %%
effnet = EfficientNetB0(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("effnet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor=0.3, patience=2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
model.compile(optimizer=optimizer, loss='categorical_crossentropy',
              metrics=[metrics.Precision(), metrics.Recall(), metrics.AUC()],
              weighted_metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,validation_split=0.2, epochs=150, verbose=1, batch_size=32,
                    callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/150
# 8/8 [==============================] - ETA: 0s - loss: 1.6842 - precision: 0.4573 - recall: 0.3856 - auc: 0.6142 - accuracy: 0.4407
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to effnet.h5
# 8/8 [==============================] - 639s 24s/step - loss: 1.6842 - precision: 0.4573 - recall: 0.3856 - auc: 0.6142 - accuracy: 0.4407 - val_loss: 1.0679 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5226 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 2/150
# 8/8 [==============================] - ETA: 0s - loss: 0.7737 - precision: 0.7343 - recall: 0.6441 - auc: 0.8539 - accuracy: 0.7076
# Epoch 2: val_accuracy did not improve from 0.50000
# 8/8 [==============================] - 5s 647ms/step - loss: 0.7737 - precision: 0.7343 - recall: 0.6441 - auc: 0.8539 - accuracy: 0.7076 - val_loss: 1.1876 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.4472 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 3/150
# 8/8 [==============================] - ETA: 0s - loss: 0.6870 - precision: 0.7717 - recall: 0.7161 - auc: 0.8948 - accuracy: 0.7331
# Epoch 3: val_accuracy did not improve from 0.50000
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.6870 - precision: 0.7717 - recall: 0.7161 - auc: 0.8948 - accuracy: 0.7331 - val_loss: 1.7776 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5141 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 4/150
# 8/8 [==============================] - ETA: 0s - loss: 0.4946 - precision: 0.8435 - recall: 0.8220 - auc: 0.9357 - accuracy: 0.8390
# Epoch 4: val_accuracy did not improve from 0.50000
# 8/8 [==============================] - 5s 647ms/step - loss: 0.4946 - precision: 0.8435 - recall: 0.8220 - auc: 0.9357 - accuracy: 0.8390 - val_loss: 1.9828 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5360 - val_accuracy: 0.5000 - lr: 3.0000e-05
# Epoch 5/150
# 8/8 [==============================] - ETA: 0s - loss: 0.4301 - precision: 0.8590 - recall: 0.8263 - auc: 0.9502 - accuracy: 0.8390
# Epoch 5: val_accuracy did not improve from 0.50000
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 8/8 [==============================] - 5s 646ms/step - loss: 0.4301 - precision: 0.8590 - recall: 0.8263 - auc: 0.9502 - accuracy: 0.8390 - val_loss: 2.5011 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5605 - val_accuracy: 0.5000 - lr: 3.0000e-05
# Epoch 6/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3799 - precision: 0.8673 - recall: 0.8305 - auc: 0.9613 - accuracy: 0.8432
# Epoch 6: val_accuracy did not improve from 0.50000
# 8/8 [==============================] - 5s 646ms/step - loss: 0.3799 - precision: 0.8673 - recall: 0.8305 - auc: 0.9613 - accuracy: 0.8432 - val_loss: 2.7607 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5814 - val_accuracy: 0.5000 - lr: 9.0000e-06
# Epoch 7/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3962 - precision: 0.8652 - recall: 0.8432 - auc: 0.9562 - accuracy: 0.8517
# Epoch 7: val_accuracy did not improve from 0.50000
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3962 - precision: 0.8652 - recall: 0.8432 - auc: 0.9562 - accuracy: 0.8517 - val_loss: 3.1017 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5971 - val_accuracy: 0.5000 - lr: 9.0000e-06
# Epoch 8/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3510 - precision: 0.8947 - recall: 0.8644 - auc: 0.9654 - accuracy: 0.8856
# Epoch 8: val_accuracy did not improve from 0.50000
# 8/8 [==============================] - 5s 646ms/step - loss: 0.3510 - precision: 0.8947 - recall: 0.8644 - auc: 0.9654 - accuracy: 0.8856 - val_loss: 3.4519 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5958 - val_accuracy: 0.5000 - lr: 2.7000e-06
# Epoch 9/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3482 - precision: 0.8821 - recall: 0.8559 - auc: 0.9666 - accuracy: 0.8602
# Epoch 9: val_accuracy did not improve from 0.50000
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 8.099999604382901e-07.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3482 - precision: 0.8821 - recall: 0.8559 - auc: 0.9666 - accuracy: 0.8602 - val_loss: 3.7510 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6208 - val_accuracy: 0.5000 - lr: 2.7000e-06
# Epoch 10/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3037 - precision: 0.9214 - recall: 0.8941 - auc: 0.9738 - accuracy: 0.9025
# Epoch 10: val_accuracy did not improve from 0.50000
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3037 - precision: 0.9214 - recall: 0.8941 - auc: 0.9738 - accuracy: 0.9025 - val_loss: 4.0667 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6250 - val_accuracy: 0.5000 - lr: 8.1000e-07
# Epoch 11/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3467 - precision: 0.8987 - recall: 0.8644 - auc: 0.9670 - accuracy: 0.8771
# Epoch 11: val_accuracy did not improve from 0.50000
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.4299998813148704e-07.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3467 - precision: 0.8987 - recall: 0.8644 - auc: 0.9670 - accuracy: 0.8771 - val_loss: 4.3938 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6250 - val_accuracy: 0.5000 - lr: 8.1000e-07
# Epoch 12/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3034 - precision: 0.9134 - recall: 0.8941 - auc: 0.9728 - accuracy: 0.8983
# Epoch 12: val_accuracy did not improve from 0.50000
# 8/8 [==============================] - 5s 646ms/step - loss: 0.3034 - precision: 0.9134 - recall: 0.8941 - auc: 0.9728 - accuracy: 0.8983 - val_loss: 4.7007 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6250 - val_accuracy: 0.5000 - lr: 2.4300e-07
# Epoch 13/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3471 - precision: 0.8777 - recall: 0.8517 - auc: 0.9681 - accuracy: 0.8602
# Epoch 13: val_accuracy did not improve from 0.50000
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to
150
# 8/8 [==============================] - ETA: 0s - loss: 0.3137 - precision: 0.9071 - recall: 0.8686 - auc: 0.9728 - accuracy: 0.8941
# Epoch 24: val_accuracy did not improve from 0.50000
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3137 - precision: 0.9071 - recall: 0.8686 - auc: 0.9728 - accuracy: 0.8941 - val_loss: 7.4098 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6250 - val_accuracy: 0.5000 - lr: 1.7715e-10
# Epoch 25/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3322 - precision: 0.9067 - recall: 0.8644 - auc: 0.9694 - accuracy: 0.8814
# Epoch 25: val_accuracy did not improve from 0.50000
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 5.314409329271186e-11.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3322 - precision: 0.9067 - recall: 0.8644 - auc: 0.9694 - accuracy: 0.8814 - val_loss: 7.5371 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6250 - val_accuracy: 0.5000 - lr: 1.7715e-10
# Epoch 26/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3329 - precision: 0.9022 - recall: 0.8602 - auc: 0.9697 - accuracy: 0.8686
# Epoch 26: val_accuracy did not improve from 0.50000
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3329 - precision: 0.9022 - recall: 0.8602 - auc: 0.9697 - accuracy: 0.8686 - val_loss: 7.6451 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6250 - val_accuracy: 0.5000 - lr: 5.3144e-11
# Epoch 27/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3114 - precision: 0.9167 - recall: 0.8856 - auc: 0.9726 - accuracy: 0.9068
# Epoch 27: val_accuracy did not improve from 0.50000
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.5943227987813556e-11.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3114 - precision: 0.9167 - recall: 0.8856 - auc: 0.9726 - accuracy: 0.9068 - val_loss: 7.7361 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6250 - val_accuracy: 0.5000 - lr: 5.3144e-11
# Epoch 28/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3346 - precision: 0.8996 - recall: 0.8729 - auc: 0.9689 - accuracy: 0.8898
# Epoch 28: val_accuracy did not improve from 0.50000
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3346 - precision: 0.8996 - recall: 0.8729 - auc: 0.9689 - accuracy: 0.8898 - val_loss: 7.8132 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6250 - val_accuracy: 0.5000 - lr: 1.5943e-11
# Epoch 29/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3207 - precision: 0.9018 - recall: 0.8559 - auc: 0.9721 - accuracy: 0.8856
# Epoch 29: val_accuracy did not improve from 0.50000
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 4.782968292260659e-12.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3207 - precision: 0.9018 - recall: 0.8559 - auc: 0.9721 - accuracy: 0.8856 - val_loss: 7.8735 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6250 - val_accuracy: 0.5000 - lr: 1.5943e-11
# Epoch 30/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3816 - precision: 0.8767 - recall: 0.8432 - auc: 0.9586 - accuracy: 0.8729
# Epoch 30: val_accuracy did not improve from 0.50000
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3816 - precision: 0.8767 - recall: 0.8432 - auc: 0.9586 - accuracy: 0.8729 - val_loss: 7.9203 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6250 - val_accuracy: 0.5000 - lr: 4.7830e-12
# Epoch 31/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3376 - precision: 0.9163 - recall: 0.8814 - auc: 0.9675 - accuracy: 0.8941
# Epoch 31: val_accuracy did not improve from 0.50000
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.4348904876781975e-12.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3376 - precision: 0.9163 - recall: 0.8814 - auc: 0.9675 - accuracy: 0.8941 - val_loss: 7.9495 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6250 - val_accuracy: 0.5000 - lr: 4.7830e-12
# Epoch 32/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3602 - precision: 0.8711 - recall: 0.8305 - auc: 0.9645 - accuracy: 0.8517
# Epoch 32: val_accuracy did not improve from 0.50000
# 8/8 [==============================] - 5s 648ms/step - loss: 0.3602 - precision: 0.8711 - recall: 0.8305 - auc: 0.9645 - accuracy: 0.8517 - val_loss: 7.9662 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6250 - val_accuracy: 0.5000 - lr: 1.4349e-12
# Epoch 33/150
# 8/8 [==============================] - ETA: 0s - loss: 0.2971 - precision: 0.8982 - recall: 0.8602 - auc: 0.9768 - accuracy: 0.8898
# Epoch 33: val_accuracy did not improve from 0.50000
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 4.304671528086723e-13.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.2971 - precision: 0.8982 - recall: 0.8602 - auc: 0.9768 - accuracy: 0.8898 - val_loss: 7.9661 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6250 - val_accuracy: 0.5000 - lr: 1.4349e-12
# Epoch 34/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3528 - precision: 0.9039 - recall: 0.8771 - auc: 0.9635 - accuracy: 0.8898
# Epoch 34: val_accuracy did not improve from 0.50000
# 8/8 [==============================] - 5s 647ms/step - loss: 0.
- val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.7510 - val_accuracy: 0.5000 - lr: 6.1767e-21
# Epoch 65/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3504 - precision: 0.8961 - recall: 0.8771 - auc: 0.9654 - accuracy: 0.8898
# Epoch 65: val_accuracy did not improve from 0.50000
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1.8530201198793154e-21.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3504 - precision: 0.8961 - recall: 0.8771 - auc: 0.9654 - accuracy: 0.8898 - val_loss: 2.3881 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.7613 - val_accuracy: 0.5000 - lr: 6.1767e-21
# Epoch 66/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3312 - precision: 0.9035 - recall: 0.8729 - auc: 0.9695 - accuracy: 0.8814
# Epoch 66: val_accuracy did not improve from 0.50000
# 8/8 [==============================] - 5s 646ms/step - loss: 0.3312 - precision: 0.9035 - recall: 0.8729 - auc: 0.9695 - accuracy: 0.8814 - val_loss: 2.2307 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.7630 - val_accuracy: 0.5000 - lr: 1.8530e-21
# Epoch 67/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3450 - precision: 0.9035 - recall: 0.8729 - auc: 0.9658 - accuracy: 0.8771
# Epoch 67: val_accuracy did not improve from 0.50000
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 5.559060238468911e-22.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3450 - precision: 0.9035 - recall: 0.8729 - auc: 0.9658 - accuracy: 0.8771 - val_loss: 2.0875 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.7638 - val_accuracy: 0.5000 - lr: 1.8530e-21
# Epoch 68/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3111 - precision: 0.9052 - recall: 0.8898 - auc: 0.9719 - accuracy: 0.9025
# Epoch 68: val_accuracy did not improve from 0.50000
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3111 - precision: 0.9052 - recall: 0.8898 - auc: 0.9719 - accuracy: 0.9025 - val_loss: 1.9545 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.7696 - val_accuracy: 0.5000 - lr: 5.5591e-22
# Epoch 69/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3203 - precision: 0.9107 - recall: 0.8644 - auc: 0.9715 - accuracy: 0.8856
# Epoch 69: val_accuracy did not improve from 0.50000
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1.6677180412484147e-22.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3203 - precision: 0.9107 - recall: 0.8644 - auc: 0.9715 - accuracy: 0.8856 - val_loss: 1.8338 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.7821 - val_accuracy: 0.5000 - lr: 5.5591e-22
# Epoch 70/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3419 - precision: 0.8805 - recall: 0.8432 - auc: 0.9688 - accuracy: 0.8644
# Epoch 70: val_accuracy improved from 0.50000 to 0.51667, saving model to effnet.h5
# 8/8 [==============================] - 6s 777ms/step - loss: 0.3419 - precision: 0.8805 - recall: 0.8432 - auc: 0.9688 - accuracy: 0.8644 - val_loss: 1.7162 - val_precision: 0.5167 - val_recall: 0.5167 - val_auc: 0.7853 - val_accuracy: 0.5167 - lr: 1.6677e-22
# Epoch 71/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3231 - precision: 0.8826 - recall: 0.8602 - auc: 0.9720 - accuracy: 0.8686
# Epoch 71: val_accuracy did not improve from 0.51667
# 8/8 [==============================] - 5s 646ms/step - loss: 0.3231 - precision: 0.8826 - recall: 0.8602 - auc: 0.9720 - accuracy: 0.8686 - val_loss: 1.6044 - val_precision: 0.5167 - val_recall: 0.5167 - val_auc: 0.7930 - val_accuracy: 0.5167 - lr: 1.6677e-22
# Epoch 72/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3192 - precision: 0.9071 - recall: 0.8686 - auc: 0.9729 - accuracy: 0.8898
# Epoch 72: val_accuracy did not improve from 0.51667
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 5.003154275206538e-23.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3192 - precision: 0.9071 - recall: 0.8686 - auc: 0.9729 - accuracy: 0.8898 - val_loss: 1.4970 - val_precision: 0.5167 - val_recall: 0.5167 - val_auc: 0.7993 - val_accuracy: 0.5167 - lr: 1.6677e-22
# Epoch 73/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3262 - precision: 0.8957 - recall: 0.8729 - auc: 0.9712 - accuracy: 0.8941
# Epoch 73: val_accuracy improved from 0.51667 to 0.55000, saving model to effnet.h5
# 8/8 [==============================] - 6s 778ms/step - loss: 0.3262 - precision: 0.8957 - recall: 0.8729 - auc: 0.9712 - accuracy: 0.8941 - val_loss: 1.3933 - val_precision: 0.5500 - val_recall: 0.5500 - val_auc: 0.8178 - val_accuracy: 0.5500 - lr: 5.0032e-23
# Epoch 74/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3521 - precision: 0.9005 - recall: 0.8432 - auc: 0.9665 - accuracy: 0.8814
# Epoch 74: val_accuracy improved from 0.55000 to 0.58333, saving model to effnet.h5
# 8/8 [==============================] - 6s 781ms/step - loss: 0.3521 - precision: 0.9005 - recall: 0.8432 - auc: 0.9665 - accuracy: 0.8814 - val_loss: 1.2966 - val_precision: 0.5862 - val_recall: 0.5667 - val_auc: 0.8220 - val_accuracy: 0.5833 - lr: 5.0032e-23
# Epoch 75/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3131 - precision: 0.9156 - recall: 0.8729 - auc: 0.9731 - accuracy: 0.9068
# Epoch 75: val_accuracy did not improve from 0.58333
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3131 - precision: 0.9156 - recall: 0.8729 - auc: 0.9731 - accuracy: 0.9068 - val_loss: 1.2019 - val_precision: 0.6034 - val_recall: 0.5833 - val_auc: 0.8283 - val_accuracy: 0.5833 - lr: 5.0032e-23
# Epoch 76/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3236 - precision: 0.9152 - recall: 0.8686 - auc: 0.9701 - accuracy: 0.8898
# Epoch 76: val_accuracy improved from 0.58333 to 0.60000, saving model to effnet.h5
# 8/8 [==============================] - 6s 780ms/step - loss: 0.3236 - precision: 0.9152 - recall: 0.8686 - auc: 0.9701 - accuracy: 0.8898 - val_loss: 1.1128 - val_precision: 0.6140 - val_recall: 0.5833 - val_auc: 0.8450 - val_accuracy: 0.6000 - lr: 5.0032e-23
# Epoch 77/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3521 - precision: 0.8899 - recall: 0.8559 - auc: 0.9650 - accuracy: 0.8771
# Epoch 77: val_accuracy improved from 0.60000 to 0.65000, saving model to effnet.h5
# 8/8 [==============================] - 6s 787ms/step - loss: 0.3521 - precision: 0.8899 - recall: 0.8559 - auc: 0.9650 - accuracy: 0.8771 - val_loss: 1.0268 - val_precision: 0.6491 - val_recall: 0.6167 - val_auc: 0.8505 - val_accuracy: 0.6500 - lr: 5.0032e-23
# Epoch 78/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3259 - precision: 0.9035 - recall: 0.8729 - auc: 0.9711 - accuracy: 0.8771
# Epoch 78: val_accuracy did not improve from 0.65000
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3259 - precision: 0.9035 - recall: 0.8729 - auc: 0.9711 - accuracy: 0.8771 - val_loss: 0.9478 - val_precision: 0.6610 - val_recall: 0.6500 - val_auc: 0.8593 - val_accuracy: 0.6500 - lr: 5.0032e-23
# Epoch 79/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3327 - precision: 0.8978 - recall: 0.8559 - auc: 0.9695 - accuracy: 0.8686
# Epoch 79: val_accuracy improved from 0.65000 to 0.66667, saving model to effnet.h5
# 8/8 [==============================] - 6s 778ms/step - loss: 0.3327 - precision: 0.8978 - recall: 0.8559 - auc: 0.9695 - accuracy: 0.8686 - val_loss: 0.8751 - val_precision: 0.7018 - val_recall: 0.6667 - val_auc: 0.8674 - val_accuracy: 0.6667 - lr: 5.0032e-23
# Epoch 80/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3472 - precision: 0.8929 - recall: 0.8475 - auc: 0.9666 - accuracy: 0.8814
# Epoch 80: val_accuracy improved from 0.66667 to 0.68333, saving model to effnet.h5
# 8/8 [==============================] - 6s 777ms/step - loss: 0.3472 - precision: 0.8929 - recall: 0.8475 - auc: 0.9666 - accuracy: 0.8814 - val_loss: 0.8084 - val_precision: 0.7193 - val_recall: 0.6833 - val_auc: 0.8749 - val_accuracy: 0.6833 - lr: 5.0032e-23
# Epoch 81/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3180 - precision: 0.9048 - recall: 0.8856 - auc: 0.9706 - accuracy: 0.8983
# Epoch 81: val_accuracy did not improve from 0.68333
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3180 - precision: 0.9048 - recall: 0.8856 - auc: 0.9706 - accuracy: 0.8983 - val_loss: 0.7517 - val_precision: 0.7193 - val_recall: 0.6833 - val_auc: 0.8824 - val_accuracy: 0.6833 - lr: 5.0032e-23
# Epoch 82/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3623 - precision: 0.8640 - recall: 0.8347 - auc: 0.9641 - accuracy: 0.8475
# Epoch 82: val_accuracy did not improve from 0.68333
#
# Epoch 82: ReduceLROnPlateau reducing learning rate to 1.5009463014946232e-23.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3623 - precision: 0.8640 - recall: 0.8347 - auc: 0.9641 - accuracy: 0.8475 - val_loss: 0.7008 - val_precision: 0.7193 - val_recall: 0.6833 - val_auc: 0.8901 - val_accuracy: 0.6833 - lr: 5.0032e-23
# Epoch 83/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3344 - precision: 0.8745 - recall: 0.8559 - auc: 0.9695 - accuracy: 0.8644
# Epoch 83: val_accuracy improved from 0.68333 to 0.70000, saving model to effnet.h5
# 8/8 [==============================] - 6s 777ms/step - loss: 0.3344 - precision: 0.8745 - recall: 0.8559 - auc: 0.9695 - accuracy: 0.8644 - val_loss: 0.6544 - val_precision: 0.7241 - val_recall: 0.7000 - val_auc: 0.9038 - val_accuracy: 0.7000 - lr: 1.5009e-23
# Epoch 84/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3140 - precision: 0.9156 - recall: 0.8729 - auc: 0.9737 - accuracy: 0.9025
# Epoch 84: val_accuracy improved from 0.70000 to 0.75000, saving model to effnet.h5
# 8/8 [==============================] - 6s 777ms/step - loss: 0.3140 - precision: 0.9156 - recall: 0.8729 - auc: 0.9737 - accuracy: 0.9025 - val_loss: 0.6146 - val_precision: 0.7544 - val_recall: 0.7167 - val_auc: 0.9108 - val_accuracy: 0.7500 - lr: 1.5009e-23
# Epoch 85/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3177 - precision: 0.9221 - recall: 0.9025 - auc: 0.9709 - accuracy: 0.9195
# Epoch 85: val_accuracy improved from 0.75000 to 0.76667, saving model to effnet.h5
# 8/8 [==============================] - 6s 796ms/step - loss: 0.3177 - precision: 0.9221 - recall: 0.9025 - auc: 0.9709 - accuracy: 0.9195 - val_loss: 0.5810 - val_precision: 0.7719 - val_recall: 0.7333 - val_auc: 0.9181 - val_accuracy: 0.7667 - lr: 1.5009e-23
# Epoch 86/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3223 - precision: 0.8816 - recall: 0.8517 - auc: 0.9722 - accuracy: 0.8686
# Epoch 86: val_accuracy improved from 0.76667 to 0.78333, saving model to effnet.h5
# 8/8 [==============================] - 6s 778ms/step - loss: 0.3223 - precision: 0.8816 - recall: 0.8517 - auc: 0.9722 - accuracy: 0.8686 - val_loss: 0.5522 - val_precision: 0.7931 - val_recall: 0.7667 - val_auc: 0.9236 - val_accuracy: 0.7833 - lr: 1.5009e-23
# Epoch 87/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3288 - precision: 0.8952 - recall: 0.8686 - auc: 0.9702 - accuracy: 0.8771
# Epoch 87: val_accuracy did not improve from 0.78333
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3288 - precision: 0.8952 - recall: 0.8686 - auc: 0.9702 - accuracy: 0.8771 - val_loss: 0.5256 - val_precision: 0.7931 - val_recall: 0.7667 - val_auc: 0.9285 - val_accuracy: 0.7833 - lr: 1.5009e-23
# Epoch 88/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3205 - precision: 0.9140 - recall: 0.8559 - auc: 0.9720 - accuracy: 0.8941
# Epoch 88: val_accuracy did not improve from 0.78333
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 4.502838715157252e-24.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3205 - precision: 0.9140 - recall: 0.8559 - auc: 0.9720 - accuracy: 0.8941 - val_loss: 0.5024 - val_precision: 0.7759 - val_recall: 0.7500 - val_auc: 0.9333 - val_accuracy: 0.7500 - lr: 1.5009e-23
# Epoch 89/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3392 - precision: 0.8811 - recall: 0.8475 - auc: 0.9677 - accuracy: 0.8644
# Epoch 89: val_accuracy improved from 0.78333 to 0.81667, saving model to effnet.h5
# 8/8 [==============================] - 6s 781ms/step - loss: 0.3392 - precision: 0.8811 - recall: 0.8475 - auc: 0.9677 - accuracy: 0.8644 - val_loss: 0.4825 - val_precision: 0.8036 - val_recall: 0.7500 - val_auc: 0.9386 - val_accuracy: 0.8167 - lr: 4.5028e-24
# Epoch 90/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3718 - precision: 0.8811 - recall: 0.8475 - auc: 0.9617 - accuracy: 0.8602
# Epoch 90: val_accuracy did not improve from 0.81667
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3718 - precision: 0.8811 - recall: 0.8475 - auc: 0.9617 - accuracy: 0.8602 - val_loss: 0.4652 - val_precision: 0.8103 - val_recall: 0.7833 - val_auc: 0.9434 - val_accuracy: 0.8167 - lr: 4.5028e-24
# Epoch 91/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3366 - precision: 0.8918 - recall: 0.8729 - auc: 0.9674 - accuracy: 0.8856
# Epoch 91: val_accuracy did not improve from 0.81667
#
# Epoch 91: ReduceLROnPlateau reducing learning rate to 1.3508515672155214e-24.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3366 - precision: 0.8918 - recall: 0.8729 - auc: 0.9674 - accuracy: 0.8856 - val_loss: 0.4504 - val_precision: 0.7966 - val_recall: 0.7833 - val_auc: 0.9473 - val_accuracy: 0.8000 - lr: 4.5028e-24
# Epoch 92/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3395 - precision: 0.8978 - recall: 0.8559 - auc: 0.9690 - accuracy: 0.8856
# Epoch 92: val_accuracy did not improve from 0.81667
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3395 - precision: 0.8978 - recall: 0.8559 - auc: 0.9690 - accuracy: 0.8856 - val_loss: 0.4375 - val_precision: 0.7966 - val_recall: 0.7833 - val_auc: 0.9501 - val_accuracy: 0.8000 - lr: 1.3509e-24
# Epoch 93/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3255 - precision: 0.9018 - recall: 0.8559 - auc: 0.9722 - accuracy: 0.8771
# Epoch 93: val_accuracy did not improve from 0.81667
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 4.052554583317428e-25.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3255 - precision: 0.9018 - recall: 0.8559 - auc: 0.9722 - accuracy: 0.8771 - val_loss: 0.4266 - val_precision: 0.7966 - val_recall: 0.7833 - val_auc: 0.9526 - val_accuracy: 0.8000 - lr: 1.3509e-24
# Epoch 94/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3275 - precision: 0.9067 - recall: 0.8644 - auc: 0.9708 - accuracy: 0.8771
# Epoch 94: val_accuracy did not improve from 0.81667
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3275 - precision: 0.9067 - recall: 0.8644 - auc: 0.9708 - accuracy: 0.8771 - val_loss: 0.4174 - val_precision: 0.8103 - val_recall: 0.7833 - val_auc: 0.9535 - val_accuracy: 0.8167 - lr: 4.0526e-25
# Epoch 95/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3338 - precision: 0.8961 - recall: 0.8771 - auc: 0.9695 - accuracy: 0.8856
# Epoch 95: val_accuracy improved from 0.81667 to 0.83333, saving model to effnet.h5
# 8/8 [==============================] - 6s 779ms/step - loss: 0.3338 - precision: 0.8961 - recall: 0.8771 - auc: 0.9695 - accuracy: 0.8856 - val_loss: 0.4091 - val_precision: 0.8448 - val_recall: 0.8167 - val_auc: 0.9557 - val_accuracy: 0.8333 - lr: 4.0526e-25
# Epoch 96/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3061 - precision: 0.9091 - recall: 0.8898 - auc: 0.9740 - accuracy: 0.8898
# Epoch 96: val_accuracy did not improve from 0.83333
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3061 - precision: 0.9091 - recall: 0.8898 - auc: 0.9740 - accuracy: 0.8898 - val_loss: 0.4028 - val_precision: 0.8448 - val_recall: 0.8167 - val_auc: 0.9565 - val_accuracy: 0.8333 - lr: 4.0526e-25
# Epoch 97/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3553 - precision: 0.8846 - recall: 0.8771 - auc: 0.9648 - accuracy: 0.8814
# Epoch 97: val_accuracy did not improve from 0.83333
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 1.2157663454129446e-25.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3553 - precision: 0.8846 - recall: 0.8771 - auc: 0.9648 - accuracy: 0.8814 - val_loss: 0.3973 - val_precision: 0.8596 - val_recall: 0.8167 - val_auc: 0.9573 - val_accuracy: 0.8333 - lr: 4.0526e-25
# Epoch 98/150
# ...
# Epoch 119/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3481 - precision: 0.8821 - recall: 0.8559 - auc: 0.9669 - accuracy: 0.8729
# Epoch 119: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 648ms/step - loss: 0.3481 - precision: 0.8821 - recall: 0.8559 - auc: 0.9669 - accuracy: 0.8729 - val_loss: 0.3826 - val_precision: 0.8793 - val_recall: 0.8500 - val_auc: 0.9576 - val_accuracy: 0.8833 - lr: 2.3930e-30
# Epoch 120/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3964 - precision: 0.8855 - recall: 0.8517 - auc: 0.9566 - accuracy: 0.8602
# Epoch 120: val_accuracy did not improve from 0.88333
#
# Epoch 120: ReduceLROnPlateau reducing learning rate to 7.178977782788201e-31.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3964 - precision: 0.8855 - recall: 0.8517 - auc: 0.9566 - accuracy: 0.8602 - val_loss: 0.3831 - val_precision: 0.8772 - val_recall: 0.8333 - val_auc: 0.9575 - val_accuracy: 0.8667 - lr: 2.3930e-30
# Epoch 121/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3487 - precision: 0.9071 - recall: 0.8686 - auc: 0.9642 - accuracy: 0.8941
# Epoch 121: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 646ms/step - loss: 0.3487 - precision: 0.9071 - recall: 0.8686 - auc: 0.9642 - accuracy: 0.8941 - val_loss: 0.3835 - val_precision: 0.8621 - val_recall: 0.8333 - val_auc: 0.9574 - val_accuracy: 0.8667 - lr: 7.1790e-31
# Epoch 122/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3276 - precision: 0.8991 - recall: 0.8686 - auc: 0.9702 - accuracy: 0.8856
# Epoch 122: val_accuracy did not improve from 0.88333
#
# Epoch 122: ReduceLROnPlateau reducing learning rate to 2.153693306624596e-31.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3276 - precision: 0.8991 - recall: 0.8686 - auc: 0.9702 - accuracy: 0.8856 - val_loss: 0.3839 - val_precision: 0.8621 - val_recall: 0.8333 - val_auc: 0.9573 - val_accuracy: 0.8667 - lr: 7.1790e-31
# Epoch 123/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3743 - precision: 0.8717 - recall: 0.8347 - auc: 0.9615 - accuracy: 0.8602
# Epoch 123: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 648ms/step - loss: 0.3743 - precision: 0.8717 - recall: 0.8347 - auc: 0.9615 - accuracy: 0.8602 - val_loss: 0.3844 - val_precision: 0.8621 - val_recall: 0.8333 - val_auc: 0.9569 - val_accuracy: 0.8667 - lr: 2.1537e-31
# Epoch 124/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3083 - precision: 0.9211 - recall: 0.8898 - auc: 0.9725 - accuracy: 0.9195
# Epoch 124: val_accuracy did not improve from 0.88333
#
# Epoch 124: ReduceLROnPlateau reducing learning rate to 6.461079778814466e-32.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3083 - precision: 0.9211 - recall: 0.8898 - auc: 0.9725 - accuracy: 0.9195 - val_loss: 0.3848 - val_precision: 0.8621 - val_recall: 0.8333 - val_auc: 0.9571 - val_accuracy: 0.8667 - lr: 2.1537e-31
# Epoch 125/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3446 - precision: 0.8908 - recall: 0.8644 - auc: 0.9655 - accuracy: 0.8856
# Epoch 125: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3446 - precision: 0.8908 - recall: 0.8644 - auc: 0.9655 - accuracy: 0.8856 - val_loss: 0.3851 - val_precision: 0.8621 - val_recall: 0.8333 - val_auc: 0.9569 - val_accuracy: 0.8667 - lr: 6.4611e-32
# Epoch 126/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3350 - precision: 0.9067 - recall: 0.8644 - auc: 0.9694 - accuracy: 0.8814
# Epoch 126: val_accuracy did not improve from 0.88333
#
# Epoch 126: ReduceLROnPlateau reducing learning rate to 1.9383240041740008e-32.
# 8/8 [==============================] - 5s 648ms/step - loss: 0.3350 - precision: 0.9067 - recall: 0.8644 - auc: 0.9694 - accuracy: 0.8814 - val_loss: 0.3854 - val_precision: 0.8621 - val_recall: 0.8333 - val_auc: 0.9567 - val_accuracy: 0.8667 - lr: 6.4611e-32
# Epoch 127/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3199 - precision: 0.9083 - recall: 0.8814 - auc: 0.9718 - accuracy: 0.8898
# Epoch 127: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 648ms/step - loss: 0.3199 - precision: 0.9083 - recall: 0.8814 - auc: 0.9718 - accuracy: 0.8898 - val_loss: 0.3857 - val_precision: 0.8621 - val_recall: 0.8333 - val_auc: 0.9567 - val_accuracy: 0.8667 - lr: 1.9383e-32
# Epoch 128/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3449 - precision: 0.8978 - recall: 0.8559 - auc: 0.9672 - accuracy: 0.8771
# Epoch 128: val_accuracy did not improve from 0.88333
#
# Epoch 128: ReduceLROnPlateau reducing learning rate to 5.814972188846155e-33.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3449 - precision: 0.8978 - recall: 0.8559 - auc: 0.9672 - accuracy: 0.8771 - val_loss: 0.3859 - val_precision: 0.8621 - val_recall: 0.8333 - val_auc: 0.9565 - val_accuracy: 0.8667 - lr: 1.9383e-32
# Epoch 129/150
# 8/8 [==============================] - ETA: 0s - loss: 0.2989 - precision: 0.9039 - recall: 0.8771 - auc: 0.9764 - accuracy: 0.8941
# Epoch 129: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 647ms/step - loss: 0.2989 - precision: 0.9039 - recall: 0.8771 - auc: 0.9764 - accuracy: 0.8941 - val_loss: 0.3863 - val_precision: 0.8621 - val_recall: 0.8333 - val_auc: 0.9565 - val_accuracy: 0.8667 - lr: 5.8150e-33
# Epoch 130/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3183 - precision: 0.8982 - recall: 0.8602 - auc: 0.9732 - accuracy: 0.8771
# Epoch 130: val_accuracy did not improve from 0.88333
#
# Epoch 130: ReduceLROnPlateau reducing learning rate to 1.7444916566538465e-33.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3183 - precision: 0.8982 - recall: 0.8602 - auc: 0.9732 - accuracy: 0.8771 - val_loss: 0.3867 - val_precision: 0.8621 - val_recall: 0.8333 - val_auc: 0.9566 - val_accuracy: 0.8667 - lr: 5.8150e-33
# Epoch 131/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3311 - precision: 0.8978 - recall: 0.8559 - auc: 0.9708 - accuracy: 0.8941
# Epoch 131: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3311 - precision: 0.8978 - recall: 0.8559 - auc: 0.9708 - accuracy: 0.8941 - val_loss: 0.3869 - val_precision: 0.8621 - val_recall: 0.8333 - val_auc: 0.9567 - val_accuracy: 0.8667 - lr: 1.7445e-33
# Epoch 132/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3449 - precision: 0.8850 - recall: 0.8475 - auc: 0.9663 - accuracy: 0.8729
# Epoch 132: val_accuracy did not improve from 0.88333
#
# Epoch 132: ReduceLROnPlateau reducing learning rate to 5.233474969961539e-34.
# 8/8 [==============================] - 5s 648ms/step - loss: 0.3449 - precision: 0.8850 - recall: 0.8475 - auc: 0.9663 - accuracy: 0.8729 - val_loss: 0.3871 - val_precision: 0.8621 - val_recall: 0.8333 - val_auc: 0.9568 - val_accuracy: 0.8667 - lr: 1.7445e-33
# Epoch 133/150
# 8/8 [==============================] - ETA: 0s - loss: 0.2927 - precision: 0.9342 - recall: 0.9025 - auc: 0.9767 - accuracy: 0.9237
# Epoch 133: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 647ms/step - loss: 0.2927 - precision: 0.9342 - recall: 0.9025 - auc: 0.9767 - accuracy: 0.9237 - val_loss: 0.3873 - val_precision: 0.8644 - val_recall: 0.8500 - val_auc: 0.9568 - val_accuracy: 0.8667 - lr: 5.2335e-34
# Epoch 134/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3325 - precision: 0.9022 - recall: 0.8602 - auc: 0.9696 - accuracy: 0.8898
# Epoch 134: val_accuracy did not improve from 0.88333
#
# Epoch 134: ReduceLROnPlateau reducing learning rate to 1.5700424634378129e-34.
# 8/8 [==============================] - 5s 649ms/step - loss: 0.3325 - precision: 0.9022 - recall: 0.8602 - auc: 0.9696 - accuracy: 0.8898 - val_loss: 0.3873 - val_precision: 0.8644 - val_recall: 0.8500 - val_auc: 0.9568 - val_accuracy: 0.8667 - lr: 5.2335e-34
# Epoch 135/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3221 - precision: 0.8952 - recall: 0.8686 - auc: 0.9729 - accuracy: 0.8771
# Epoch 135: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3221 - precision: 0.8952 - recall: 0.8686 - auc: 0.9729 - accuracy: 0.8771 - val_loss: 0.3876 - val_precision: 0.8644 - val_recall: 0.8500 - val_auc: 0.9565 - val_accuracy: 0.8667 - lr: 1.5700e-34
# Epoch 136/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3190 - precision: 0.9127 - recall: 0.8856 - auc: 0.9710 - accuracy: 0.8983
# Epoch 136: val_accuracy did not improve from 0.88333
#
# Epoch 136: ReduceLROnPlateau reducing learning rate to 4.710127459190061e-35.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3190 - precision: 0.9127 - recall: 0.8856 - auc: 0.9710 - accuracy: 0.8983 - val_loss: 0.3878 - val_precision: 0.8644 - val_recall: 0.8500 - val_auc: 0.9564 - val_accuracy: 0.8667 - lr: 1.5700e-34
# Epoch 137/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3181 - precision: 0.9115 - recall: 0.8729 - auc: 0.9719 - accuracy: 0.8941
# Epoch 137: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3181 - precision: 0.9115 - recall: 0.8729 - auc: 0.9719 - accuracy: 0.8941 - val_loss: 0.3881 - val_precision: 0.8644 - val_recall: 0.8500 - val_auc: 0.9562 - val_accuracy: 0.8667 - lr: 4.7101e-35
# Epoch 138/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3346 - precision: 0.9207 - recall: 0.8856 - auc: 0.9688 - accuracy: 0.8941
# Epoch 138: val_accuracy did not improve from 0.88333
#
# Epoch 138: ReduceLROnPlateau reducing learning rate to 1.413038254976174e-35.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3346 - precision: 0.9207 - recall: 0.8856 - auc: 0.9688 - accuracy: 0.8941 - val_loss: 0.3882 - val_precision: 0.8644 - val_recall: 0.8500 - val_auc: 0.9562 - val_accuracy: 0.8667 - lr: 4.7101e-35
# Epoch 139/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3365 - precision: 0.8879 - recall: 0.8729 - auc: 0.9684 - accuracy: 0.8814
# Epoch 139: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3365 - precision: 0.8879 - recall: 0.8729 - auc: 0.9684 - accuracy: 0.8814 - val_loss: 0.3881 - val_precision: 0.8644 - val_recall: 0.8500 - val_auc: 0.9562 - val_accuracy: 0.8667 - lr: 1.4130e-35
# Epoch 140/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3081 - precision: 0.8987 - recall: 0.8644 - auc: 0.9749 - accuracy: 0.8898
# Epoch 140: val_accuracy did not improve from 0.88333
#
# Epoch 140: ReduceLROnPlateau reducing learning rate to 4.239114592736966e-36.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3081 - precision: 0.8987 - recall: 0.8644 - auc: 0.9749 - accuracy: 0.8898 - val_loss: 0.3882 - val_precision: 0.8644 - val_recall: 0.8500 - val_auc: 0.9562 - val_accuracy: 0.8667 - lr: 1.4130e-35
# Epoch 141/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3492 - precision: 0.8865 - recall: 0.8602 - auc: 0.9661 - accuracy: 0.8729
# Epoch 141: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 648ms/step - loss: 0.3492 - precision: 0.8865 - recall: 0.8602 - auc: 0.9661 - accuracy: 0.8729 - val_loss: 0.3882 - val_precision: 0.8644 - val_recall: 0.8500 - val_auc: 0.9565 - val_accuracy: 0.8667 - lr: 4.2391e-36
# Epoch 142/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3109 - precision: 0.9167 - recall: 0.8856 - auc: 0.9716 - accuracy: 0.9110
# Epoch 142: val_accuracy did not improve from 0.88333
#
# Epoch 142: ReduceLROnPlateau reducing learning rate to 1.2717343993450343e-36.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3109 - precision: 0.9167 - recall: 0.8856 - auc: 0.9716 - accuracy: 0.9110 - val_loss: 0.3883 - val_precision: 0.8667 - val_recall: 0.8667 - val_auc: 0.9562 - val_accuracy: 0.8667 - lr: 4.2391e-36
# Epoch 143/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3197 - precision: 0.9214 - recall: 0.8941 - auc: 0.9713 - accuracy: 0.9110
# Epoch 143: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3197 - precision: 0.9214 - recall: 0.8941 - auc: 0.9713 - accuracy: 0.9110 - val_loss: 0.3883 - val_precision: 0.8667 - val_recall: 0.8667 - val_auc: 0.9562 - val_accuracy: 0.8667 - lr: 1.2717e-36
# Epoch 144/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3127 - precision: 0.9167 - recall: 0.8856 - auc: 0.9739 - accuracy: 0.9025
# Epoch 144: val_accuracy did not improve from 0.88333
#
# Epoch 144: ReduceLROnPlateau reducing learning rate to 3.8152030904153805e-37.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3127 - precision: 0.9167 - recall: 0.8856 - auc: 0.9739 - accuracy: 0.9025 - val_loss: 0.3885 - val_precision: 0.8644 - val_recall: 0.8500 - val_auc: 0.9563 - val_accuracy: 0.8667 - lr: 1.2717e-36
# Epoch 145/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3483 - precision: 0.8711 - recall: 0.8305 - auc: 0.9667 - accuracy: 0.8475
# Epoch 145: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 648ms/step - loss: 0.3483 - precision: 0.8711 - recall: 0.8305 - auc: 0.9667 - accuracy: 0.8475 - val_loss: 0.3885 - val_precision: 0.8667 - val_recall: 0.8667 - val_auc: 0.9563 - val_accuracy: 0.8667 - lr: 3.8152e-37
# Epoch 146/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3363 - precision: 0.8816 - recall: 0.8517 - auc: 0.9680 - accuracy: 0.8729
# Epoch 146: val_accuracy did not improve from 0.88333
#
# Epoch 146: ReduceLROnPlateau reducing learning rate to 1.1445609002196838e-37.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3363 - precision: 0.8816 - recall: 0.8517 - auc: 0.9680 - accuracy: 0.8729 - val_loss: 0.3885 - val_precision: 0.8667 - val_recall: 0.8667 - val_auc: 0.9562 - val_accuracy: 0.8667 - lr: 3.8152e-37
# Epoch 147/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3355 - precision: 0.8996 - recall: 0.8729 - auc: 0.9686 - accuracy: 0.8814
# Epoch 147: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3355 - precision: 0.8996 - recall: 0.8729 - auc: 0.9686 - accuracy: 0.8814 - val_loss: 0.3886 - val_precision: 0.8667 - val_recall: 0.8667 - val_auc: 0.9562 - val_accuracy: 0.8667 - lr: 1.1446e-37
# Epoch 148/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3186 - precision: 0.9292 - recall: 0.8898 - auc: 0.9699 - accuracy: 0.9153
# Epoch 148: val_accuracy did not improve from 0.88333
#
# Epoch 148: ReduceLROnPlateau reducing learning rate to 3.4336825661343984e-38.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3186 - precision: 0.9292 - recall: 0.8898 - auc: 0.9699 - accuracy: 0.9153 - val_loss: 0.3890 - val_precision: 0.8667 - val_recall: 0.8667 - val_auc: 0.9562 - val_accuracy: 0.8667 - lr: 1.1446e-37
# Epoch 149/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3203 - precision: 0.9009 - recall: 0.8856 - auc: 0.9716 - accuracy: 0.8856
# Epoch 149: val_accuracy did not improve from 0.88333
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3203 - precision: 0.9009 - recall: 0.8856 - auc: 0.9716 - accuracy: 0.8856 - val_loss: 0.3888 - val_precision: 0.8667 - val_recall: 0.8667 - val_auc: 0.9560 - val_accuracy: 0.8667 - lr: 3.4337e-38
# Epoch 150/150
# 8/8 [==============================] - ETA: 0s - loss: 0.3204 - precision: 0.9062 - recall: 0.8602 - auc: 0.9726 - accuracy: 0.8898
# Epoch 150: val_accuracy did not improve from 0.88333
#
# Epoch 150: ReduceLROnPlateau reducing learning rate to 1.0301047866559011e-38.
# 8/8 [==============================] - 5s 647ms/step - loss: 0.3204 - precision: 0.9062 - recall: 0.8602 - auc: 0.9726 - accuracy: 0.8898 - val_loss: 0.3888 - val_precision: 0.8667 - val_recall: 0.8667 - val_auc: 0.9562 - val_accuracy: 0.8667 - lr: 3.4337e-38

# %%
filterwarnings('ignore')

epochs = [i for i in range(150)]
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy', size=18, fontweight='bold',
         fontname='monospace', color=colors_dark[1],y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, marker='o',markerfacecolor=colors_green[2], color=colors_green[3],
           label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, marker='o',markerfacecolor=colors_red[2], color=colors_red[3],
           label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss, marker='o',markerfacecolor=colors_green[2], color=colors_green[3],
           label = 'Training Loss')
ax[1].plot(epochs, val_loss, marker='o',markerfacecolor=colors_red[2], color=colors_red[3],
           label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')

fig.show()

# %%
# Plot the chart for accuracy and loss on both training and validation
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
auc = history.history['auc']
val_auc = history.history['val_auc']
precision = history.history['precision']
val_precision = history.history['val_precision']
recall = history.history['recall']
val_recall = history.history['val_recall']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.figure()

plt.plot(epochs, auc, 'r', label='Training C-statistic')
plt.plot(epochs, val_auc, 'b', label='Validation C-statistic')
plt.title('Training and validation C-statistic')
plt.legend()
plt.figure()

plt.plot(epochs, precision, 'r', label='Training precision')
plt.plot(epochs, val_precision, 'b', label='Validation precision')
plt.title('Training and validation precision')
plt.legend()
plt.figure()

plt.plot(epochs, recall, 'r', label='Training recall')
plt.plot(epochs, val_recall, 'b', label='Validation recall')
plt.title('Training and validation recall')
plt.legend()

plt.show()

# %%
pred1 = model.predict(X_train)
pred1 = np.argmax(pred1,axis=1)
y_train_new = np.argmax(y_train,axis=1)
# Out:
# 10/10 [==============================] - 2s 187ms/step

# %%
print(classification_report(y_train_new,pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91       136
#            1       0.80      0.94      0.86        78
#            2       0.89      0.90      0.90        82
#
#     accuracy                           0.89       296
#    macro avg       0.88      0.90      0.89       296
# weighted avg       0.90      0.89      0.89       296

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 3/3 [==============================] - 5s 3s/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.82      0.89        34
#            1       0.52      0.92      0.67        12
#            2       0.88      0.75      0.81        28
#
#     accuracy                           0.81        74
#    macro avg       0.79      0.83      0.79        74
# weighted avg       0.86      0.81      0.82        74

# %%
colors_dark = ["#1F1F1F", "#313131", '#636363', '#AEAEAE', '#DADADA']
colors_red = ["#331313", "#582626", '#9E1717', '#D35151', '#E9B4B4']
colors_green = ['#01411C', '#4B6F44', '#4F7942', '#74C365', '#D0F0C0']

# %%
import seaborn as sns

fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True,
            cmap=colors_green[::-1],alpha=0.7,linewidths=2,linecolor=colors_dark[3])
fig.text(s='Heatmap of the Confusion Matrix', size=18,fontweight='bold',
         fontname='monospace', color=colors_dark[1],y=0.92,x=0.28,alpha=0.8)

plt.show()
